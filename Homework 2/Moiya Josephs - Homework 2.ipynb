# %% [markdown]
# ## Week 3 Homework
# ### Moiya Josephs
#
#
# #### Ask:
#
# - Load a graph dataset of your choosing from a text file or other source.  If you take a large network dataset from the web (such as from Stanford Large Network Dataset Collection), please feel free at this point to load just a small subset of the nodes and edges.
# - Create basic analysis on the graph, including the graph’s diameter, and at least one other metric of your choosing.  You may either code the functions by hand (to build your intuition and insight), or use functions in an existing package.
# - Use a visualization tool of your choice (NetworkX, Gephi, Pyvis, etc.) to display information.
#
# #### Data:
#
# The data used for this homework was taken from The Network Data Repository. The title of these data was "aves-geese-female-foraging". This network dataset recorded animals grazing on the same patch during a sampling period (15 days). They were assumed to be associating (gambit of the group).

# %%
import networkx as net

o=net.Graph()

G_edges = net.read_edgelist("aves-geese-female-foraging.edges", nodetype=int, data=(("Type", str),))

# %% [markdown]
# The number of nodes in this dataset are 20. The number of animals observed in this dataset is 20.

# %%
G_edges.number_of_nodes()
# Out:
# 20

# %% [markdown]
# The number of edges in this graph are 190. There are 190 connections in this network.

# %%
G_edges.number_of_edges()
# Out:
# 190

# %% [markdown]
# The diameter of the graph is 1.

# %% [markdown]
# net.diameter(G_edges)

# %%
net.draw(G_edges, with_labels=True, font_weight='bold')

# %% [markdown]
# The figure above shows the network created using `Networkx` visualization tool.

# %% [markdown]
# Source:
# Network Data Repository. (n.d.). Aves-geese-female-foraging: Animal social networks. https://networkrepository.com/aves-geese-female-foraging.php
