# %% [markdown]
# # Week 2 Assignment
# ## Moiya Josephs
#
# ### Ask:
#
# When software developers are starting to work in a new environment, they are encouraged to start with a simple
# “beachhead” program.
#
# In this assignment, you’re asked to create the nodes and edges for a basic graph, such as the Krackhardt kite shown
# below. (You’re welcome to substitute data of your own choosing).

# %%
import networkx as net

o=net.Graph()

o.add_edge('Wakefield','Nereid')
o.add_edge('Nereid','Times Square')
o.add_edge('Woodlawn','Dyre')
o.add_edge('Dyre','Flatbush')
o.add_edge('Flatbush','Astoria')
o.add_edge('Astoria','Hells Kitchen')
o.add_edge('Astoria','Chelsea')
o.add_edge('Nereid','Woodlawn')
net.draw(o, with_labels = True)
net.write_pajek(o,'Assignment1_hellograph.net')
